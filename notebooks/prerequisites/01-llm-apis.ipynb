# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### GEMINI 2.5 FLASH

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["you are a helpful assistant", "can you print random 10 words"]
)

print(response.text)
# Out:
# Here are 10 random words for you:
#
# 1.  **Whisper**
# 2.  **Crimson**
# 3.  **Journey**
# 4.  **Enigma**
# 5.  **Shimmer**
# 6.  **Velvet**
# 7.  **Quasar**
# 8.  **Ephemeral**
# 9.  **Luminous**
# 10. **Cascade**

# %%
response.usage_metadata
# Out:
# GenerateContentResponseUsageMetadata(
#   candidates_token_count=88,
#   prompt_token_count=14,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=14
#     ),
#   ],
#   thoughts_token_count=30,
#   total_token_count=132
# )

# %% [markdown]
# ### GROQ

# %%
from groq import Groq

client = Groq(api_key=os.environ.get("GROQ_API_KEY"))
chat_completion = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "you are a helpful assistant"},
        {"role": "user", "content": "can you print random 10 words"}
    ],
    model="llama-3.3-70b-versatile"
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 10 random words:
# 1. Cloud
# 2. Space
# 3. Diamond
# 4. Computer
# 5. Library
# 6. Banana
# 7. Guitar
# 8. Bicycle
# 9. Coffee
# 10. Butterfly

# %%
chat_completion.usage
# Out:
# CompletionUsage(completion_tokens=47, prompt_tokens=47, total_tokens=94, completion_time=0.129075366, completion_tokens_details=None, prompt_time=0.00447496, prompt_tokens_details=None, queue_time=0.06792064, total_time=0.133550326)
